# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dir = 'Downloads/IMS/1st_test/1st_test'
merged_data = pd.DataFrame()

for filename in os.listdir(data_dir):
    print(filename)
    dataset=pd.read_csv(os.path.join(data_dir, filename), sep='\t')
    dataset_mean_abs = np.array(dataset.abs().mean())
    dataset_mean_abs = pd.DataFrame(dataset_mean_abs.reshape(1,8))
    dataset_mean_abs.index = [filename]
    merged_data = merged_data.append(dataset_mean_abs)

merged_data.columns = ['Bearing 1','1','Bearing 2','2','Bearing 3','3','bearing 4','4']
# Out:
# 2003.10.22.12.06.24
# 2003.10.22.12.09.13
# 2003.10.22.12.14.13
# 2003.10.22.12.19.13
# 2003.10.22.12.24.13
# 2003.10.22.12.29.13
# 2003.10.22.12.34.13
# 2003.10.22.12.39.13
# 2003.10.22.12.44.13
# 2003.10.22.12.49.13
# 2003.10.22.12.54.13
# 2003.10.22.12.59.13
# 2003.10.22.13.04.13
# 2003.10.22.13.09.13
# 2003.10.22.13.14.13
# 2003.10.22.13.19.13
# 2003.10.22.13.24.13
# 2003.10.22.13.29.13
# 2003.10.22.13.34.13
# 2003.10.22.13.39.13
# 2003.10.22.13.44.13
# 2003.10.22.13.49.13
# 2003.10.22.13.54.13
# 2003.10.22.13.59.13
# 2003.10.22.14.04.13
# 2003.10.22.14.09.13
# 2003.10.22.14.14.13
# 2003.10.22.14.19.13
# 2003.10.22.14.24.13
# 2003.10.22.14.29.13
# 2003.10.22.14.34.13
# 2003.10.22.14.39.13
# 2003.10.22.14.44.13
# 2003.10.22.14.49.13
# 2003.10.22.14.54.13
# 2003.10.22.14.59.13
# 2003.10.22.15.04.13
# 2003.10.22.15.09.13
# 2003.10.22.15.14.13
# 2003.10.22.15.19.13
# 2003.10.22.15.24.13
# 2003.10.22.15.29.13
# 2003.10.22.15.37.48
# 2003.10.22.15.44.13
# 2003.10.22.15.54.13
# ...

# %%
merged_data.index = pd.to_datetime(merged_data.index, format='%Y.%m.%d.%H.%M.%S')
merged_data = merged_data.sort_index()
#merged_data.to_csv('merged_dataset_BearingTest_2.csv')
merged_data.head()
# Out:
#                      Bearing 1  Bearing 2  Bearing 3  Bearing 4
# 2004-02-12 10:32:39   0.058333   0.071832   0.083242   0.043067
# 2004-02-12 10:42:39   0.058995   0.074006   0.084435   0.044541
# 2004-02-12 10:52:39   0.060236   0.074227   0.083926   0.044443
# 2004-02-12 11:02:39   0.061455   0.073844   0.084457   0.045081
# 2004-02-12 11:12:39   0.061361   0.075609   0.082837   0.045118

# %%
merged_data.plot(figsize = (12,6))
# Out:
# <AxesSubplot:>

# %%
d=pd.read_csv(os.path.join(data_dir, '2003.11.25.23.19.56'),sep='\t')
d.columns=[1,2,3,4,5,6,7,8]
d[1].plot(figsize = (12,6),color='black')
plt.title("Raw data")
plt.xlabel("Time (20,480)")
plt.ylabel("Sensor value")
# Out:
# Text(0, 0.5, 'Sensor value')

# %%
d=pd.read_csv(os.path.join('Downloads/IMS/1st_test/1st_test', '2003.11.25.23.19.56'),sep='\t')
d.columns=[1,2,3,4,5,6,7,8]
d.plot(figsize = (12,6), color='black')
# Out:
# <AxesSubplot:>

# %%
data_fft = abs(np.fft.fft(d[1]))
data_fft
plt.plot(data_fft[range(int(len(data_fft)/2))],color='black')
plt.title("FFT")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
# Out:
# Text(0, 0.5, 'Amplitude')
